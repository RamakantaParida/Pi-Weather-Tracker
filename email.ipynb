# %%
# Ensure you have the latest version of the OpenAI Python library installed:
# pip install --upgrade openai
import requests
'''import openai
import os

# Set your OpenAI API key in your environment variables or replace 'os.getenv("OPENAI_API_KEY")' with your actual key as a string
openai.api_key = "sk-proj-iv0ECCAUt3HAM4oIBJsHT3BlbkFJpQbJViqrXEOQOW1u5NuH"



# Define the model you want to use
MODEL = "gpt-3.5-turbo"

def get_response(weather_data):
    response = openai.ChatCompletion.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": "Imagine yourself as Weather Guru, you have to inspect the weather data and tell people what to do, keep it short "},
            {"role": "user", "content": weather_data},
        ],
        temperature=0,
    )

    # Print the content of the response
    return response['choices'][0]['message']['content']'''


def get_weather(city, api_key, units='metric', lang='en'):
    try:
        url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid={api_key}&units={units}&lang={lang}"
        response = requests.get(url)
        response.raise_for_status()  # Raise an exception for 4xx and 5xx status codes
        return response.json()
    except requests.exceptions.RequestException as e:
        print(f"Error fetching weather data: {e}")
        return None

def get_air_pollution(lat, lon, api_key):
    try:
        url = f"http://api.openweathermap.org/data/2.5/air_pollution?lat={lat}&lon={lon}&appid={api_key}"
        response = requests.get(url)
        response.raise_for_status()  # Raise an exception for 4xx and 5xx status codes
        return response.json()
    except requests.exceptions.RequestException as e:
        print(f"Error fetching air pollution data: {e}")
        return None

def get_wind_direction(degrees):
    directions = ["North", "North East", "East", "South East", "South", "South West", "West", "North West"]
    index = round(degrees / 45) % 8
    return directions[index]

def fetch_country_name(country_code):
    country_api_url = f"https://restcountries.com/v3.1/alpha?codes={country_code}"
    try:
        response = requests.get(country_api_url)
        response.raise_for_status()
        data = response.json()
        return data[0]['name']['common']
    except Exception as e:
        print(f"Error fetching country data: {e}")
        return "Country data not available"


def print_weather(weather_data):
    print(f'Country: {country_name}')
    print(f'City: {weather_data["name"]}')
    print(f'Coordinates: [{weather_data["coord"]["lon"]}, {weather_data["coord"]["lat"]}]')
    print(f'Visibility: {weather_data["visibility"]}m')
    print(f'Weather: {weather_data["weather"][0]["description"].capitalize()}')
    print(f'Temperature: {weather_data["main"]["temp"]}°C')
    print(f'Feels Like: {weather_data["main"]["feels_like"]}°C')
    print(f'Minimum Temperature: {weather_data["main"]["temp_min"]}°C')
    print(f'Maximum Temperature: {weather_data["main"]["temp_max"]}°C')
    print(f'Pressure: {weather_data["main"]["pressure"]}hPa')
    print(f'Humidity: {weather_data["main"]["humidity"]}%')
    print(f'Wind Speed: {weather_data["wind"]["speed"]}m/s')
    print(f'Wind Direction: {get_wind_direction(weather_data["wind"]["deg"])}')

def print_air_pollution(air_pollution_data):
    print("\nAir Pollution Data:")
    aqi = air_pollution_data['list'][0]['main']['aqi']
    print("Components:")
    components = air_pollution_data['list'][0]['components']
    for component, value in components.items():
        print(f"{component}: {value}")
    aqi_levels = ["Good", "Fair", "Moderate", "Poor", "Very Poor"]
    if 1 <= aqi <= 5:
        print(f"Air Quality: {aqi_levels[aqi-1]}")
    else:
        print("Unknown AQI value")

# Call the function with the weather data
city = "Patia"
api_key = "babb2568d2f0a307fa4023b8ffd9a7ac"
weather_data = get_weather(city, api_key)
country_code = weather_data["sys"]["country"]
country_name = fetch_country_name(country_code)
print_weather(weather_data)

lat, lon = weather_data["coord"]["lat"], weather_data["coord"]["lon"]
air_pollution_data = get_air_pollution(lat, lon, api_key)
print_air_pollution(air_pollution_data)

weather_string = f'Country: {weather_data["sys"]["country"]} City: {weather_data["name"]} Coordinates: [{weather_data["coord"]["lon"]}, {weather_data["coord"]["lat"]}] Visibility: {weather_data["visibility"]}m Weather: {weather_data["weather"][0]["description"].capitalize()} Temperature: {weather_data["main"]["temp"]}°C Feels Like: {weather_data["main"]["feels_like"]}°C Minimum Temperature: {weather_data["main"]["temp_min"]}°C Maximum Temperature: {weather_data["main"]["temp_max"]}°C Pressure: {weather_data["main"]["pressure"]}hPa Humidity: {weather_data["main"]["humidity"]}% Wind Speed: {weather_data["wind"]["speed"]}m/s Wind Direction: {get_wind_direction(weather_data["wind"]["deg"])}'
#final = get_response(weather_string)
#print(final)
# Out:
# Error fetching country data: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# Country: Country data not available
# City: Patía
# Coordinates: [-77.0527, 2.069]
# Visibility: 10000m
# Weather: Overcast clouds
# Temperature: 22.53°C
# Feels Like: 22.9°C
# Minimum Temperature: 22.53°C
# Maximum Temperature: 22.53°C
# Pressure: 1013hPa
# Humidity: 79%
# Wind Speed: 0.41m/s
# Wind Direction: North West
#
# Air Pollution Data:
# Components:
# co: 253.68
# no: 0
# no2: 0.94
# o3: 5.54
# so2: 0.98
# pm2_5: 3.41
# pm10: 3.83
# nh3: 2.66
# Air Quality: Good

# %%
import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown


def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

GOOGLE_API_KEY='AIXXXXXXXXXXXXXXXXXXXXXXXXXXWE'

genai.configure(api_key=GOOGLE_API_KEY)

model = genai.GenerativeModel('gemini-1.0-pro')

system_configuration = 'As a weather expert, after inspecting todays weather data tell in simplest words  what a farmer do meanwhile. Imp: remove any formatting like * and make the response short and simplistic'

weather_string = f' Country: {weather_data["sys"]["country"]} City: {weather_data["name"]} Coordinates: [{weather_data["coord"]["lon"]}, {weather_data["coord"]["lat"]}] Visibility: {weather_data["visibility"]}m Weather: {weather_data["weather"][0]["description"].capitalize()} Temperature: {weather_data["main"]["temp"]}°C Feels Like: {weather_data["main"]["feels_like"]}°C Minimum Temperature: {weather_data["main"]["temp_min"]}°C Maximum Temperature: {weather_data["main"]["temp_max"]}°C Pressure: {weather_data["main"]["pressure"]}hPa Humidity: {weather_data["main"]["humidity"]}% Wind Speed: {weather_data["wind"]["speed"]}m/s Wind Direction: {get_wind_direction(weather_data["wind"]["deg"])}'

response = model.generate_content(system_configuration + weather_string)

final = response.text
print(final)
# Out:
# Farmer should avoid outdoor work during afternoon due to high temperature and humidity.

# %%
def get_weather_emoji(describe):
    weather_emojis = {
        'Thunderstorm': '⛈️',
        'Drizzle': '🌦️',
        'Rain': '☔',
        'Snow': '🌨️',
        'Atmosphere': '🏞️',
        'Clear': '☀️',
        'Clouds': '☁️'
    }

    Thunderstorm = [
        "thunderstorm with light rain",
        "thunderstorm with rain",
        "thunderstorm with heavy rain",
        "light thunderstorm",
        "thunderstorm",
        "heavy thunderstorm",
        "ragged thunderstorm",
        "thunderstorm with light drizzle",
        "thunderstorm with drizzle",
        "thunderstorm with heavy drizzle"
    ]

    Drizzle = [
        "light intensity drizzle",
        "drizzle",
        "heavy intensity drizzle",
        "light intensity drizzle rain",
        "drizzle rain",
        "heavy intensity drizzle rain",
        "shower rain and drizzle",
        "heavy shower rain and drizzle",
        "shower drizzle"
    ]

    Rain = [
        "light rain",
        "moderate rain",
        "heavy intensity rain",
        "very heavy rain",
        "extreme rain",
        "freezing rain",
        "light intensity shower rain",
        "shower rain",
        "heavy intensity shower rain",
        "ragged shower rain"
    ]

    Snow = [
        "light snow",
        "snow",
        "heavy snow",
        "sleet",
        "light shower sleet",
        "shower sleet",
        "light rain and snow",
        "rain and snow",
        "light shower snow",
        "shower snow",
        "heavy shower snow"
    ]

    Atmosphere = [
        "mist",
        "smoke",
        "haze",
        "sand/dust whirls",
        "fog",
        "sand",
        "dust",
        "volcanic ash",
        "squalls",
        "tornado"
    ]

    Clear = ["clear sky"]

    Clouds = [
        "few clouds",
        "scattered clouds",
        "broken clouds",
        "overcast clouds"
    ]

    all_conditions = {
        'Thunderstorm': Thunderstorm,
        'Drizzle': Drizzle,
        'Rain': Rain,
        'Snow': Snow,
        'Atmosphere': Atmosphere,
        'Clear': Clear,
        'Clouds': Clouds
    }

    # Extracting weather description from the set
    weather_description = next(iter(describe))

    # Find the corresponding emoji
    for weather, conditions in all_conditions.items():
        if weather_description.lower() in conditions:
            return weather_emojis[weather]

    return "Weather condition not found"

# Example usage:
weather_description = {weather_data["weather"][0]["description"].lower()}
emoji = get_weather_emoji(weather_description)
print(emoji)
# Out:
# 🏞️

# %%
import smtplib
from email.message import EmailMessage


# Email details
sender_email = 'info.weathertracker@gmail.com'
sender_name = 'Weather Tracker'
sender_app_password = 'xxxxxxxxxxxxx'
recipient_email = 'parida.rama.email@gmail.com'
email_subject ='Weather Report'

# Create an EmailMessage object
msg = EmailMessage()
msg['Subject'] = email_subject
msg['From'] = sender_name + " <" + sender_email + ">"
msg['To'] = recipient_email
#msg.set_content("This is a test mail")

# Create an HTML table
html_content = f"""
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width">
</head>
<body style="font-family: Arial, sans-serif; background-color: #f0f0f0; margin: 0; padding: 0;">
    <div class="container" style="max-width: 400px; margin: 0 auto; padding: 20px; background-color: #fff; border-radius: 10px; box-shadow: 0 2px 6px rgba(0, 0, 0, 0.1);">
        <div class="weather-info" style="background: linear-gradient(to bottom, #3498db, #2980b9); color: #fff; padding: 20px; border-radius: 10px; text-align: center;">
            <h1 style="font-size: 24px; margin-bottom: 10px; color: #fff;">Today's Weather</h1>
            <p class="location" style="font-size: 20px; margin-bottom: 10px; color: #fff;">{weather_data["name"]}, {country_name}</p>
            <p class="temperature" style="font-size: 36px; font-weight: bold; color: #fff;">{weather_data["main"]["temp"]} °C</p>
            <p class="emoji" style="font-size: 80px; color: #fff;">{emoji}</p>
            <p class="details" style="font-size: 16px; color: #fff;">{final}</p>
        </div>
    </div>
</body>
</html>"""


# Attach the HTML content to the email
msg.set_content(html_content, subtype='html')

# Send the email
with smtplib.SMTP_SSL('smtp.gmail.com', 465) as server:
    server.login(sender_email, sender_app_password)
    server.send_message(msg)

print('Email Sent')
# Out:
# Email Sent
